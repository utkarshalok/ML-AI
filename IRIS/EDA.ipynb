# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv("iris.csv")

# %%
iris.plot(kind="scatter",x='sepal_length',y='sepal_width')
plt.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(iris,hue="species").map(plt.scatter,"sepal_length","sepal_width").add_legend();
plt.show()

# %%
#Pair Plot
plt.close
sns.pairplot(iris,hue='species')
plt.show()

# %%
plt.close()
sns.FacetGrid(iris,hue="species",size=10).map(sns.distplot,"petal_width").add_legend()

plt.show()
# Out:
# C:\Users\Utkarsh Alok\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Utkarsh Alok\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Utkarsh Alok\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#PDF and CDF
iris_setosa=iris.loc[iris['species']=='setosa']
iris_virginica=iris.loc[iris['species']=='virginica']
iris_versicolor=iris.loc[iris['species']=='versicolor']

counts, bin_edges=np.histogram(iris_setosa['petal_length'],bins=10,density=True)
pdf=counts/sum(counts)
print(bin_edges)
print(counts)

#CDF
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

#plt.show()

#VIRGINICA

countsvi, bin_edgesvi=np.histogram(iris_virginica['petal_length'],bins=10,density=True)
pdfvi=countsvi/sum(countsvi)
print(bin_edgesvi)
print(countsvi)

#CDF
cdfvi=np.cumsum(pdfvi)
plt.plot(bin_edgesvi[1:],pdfvi)
plt.plot(bin_edgesvi[1:],cdfvi)

#plt.show()

#VERSICOLOR

countsvc, bin_edgesvc=np.histogram(iris_versicolor['petal_length'],bins=10,density=True)
pdfvc=countsvc/sum(countsvc)
print(bin_edgesvc)
print(countsvc)

#CDF
cdfvc=np.cumsum(pdfvc)
plt.plot(bin_edgesvc[1:],pdfvc)
plt.plot(bin_edgesvc[1:],cdfvc)

plt.show()
# Out:
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# [0.22222222 0.22222222 0.44444444 1.55555556 2.66666667 3.11111111
#  1.55555556 0.88888889 0.         0.44444444]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]
# [0.08333333 0.41666667 1.         0.33333333 0.75       0.66666667
#  0.41666667 0.16666667 0.08333333 0.25      ]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]
# [0.0952381  0.19047619 0.28571429 0.19047619 0.76190476 0.66666667
#  0.57142857 0.95238095 0.66666667 0.38095238]

# %%
np.mean(iris_setosa["petal_length"])
np.median(iris_setosa["petal_length"])

print(np.percentile(iris_setosa["petal_length"],[25,50,100]))
# Out:
# [1.4 1.5 1.9]

# %%
sns.boxplot(x="species",y="petal_length",data=iris)
plt.show()

# %%
sns.violinplot(x="species",y="petal_length",size=20,data=iris)
plt.show()
